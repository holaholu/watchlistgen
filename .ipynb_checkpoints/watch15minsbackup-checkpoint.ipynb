VTR
VXX
VZ
WAB
WBA
WBD
WDC
WFC
WM
WMB
WMT
WU
WY
WYNN
X
XBI
XEL
XHB
XLB
XLC
XLE
XLF
XLI
XLK
XLP
XLRE
XLU
XLV
XLY
XOM
XOP
XRT
XRX
XSP
XYZ
YELP
YINN
ZION
ZM
"""

# ==========================================
# 2. DATA PROCESSING
# ==========================================
def get_clean_tickers():
    raw_tickers = [t.strip() for t in RAW_LIST.split('\n') if t.strip()]
    raw_tickers = list(set(raw_tickers))
    
    yahoo_tickers = []
    reverse_map = {} 
    
    for t in raw_tickers:
        y_tick = TICKER_MAP.get(t, t) 
        if t not in TICKER_MAP:
            y_tick = y_tick.replace('.', '-')
        yahoo_tickers.append(y_tick)
        reverse_map[y_tick] = t
        
    return yahoo_tickers, reverse_map

def fetch_twelve_data(symbol, api_key, lookback_days=100):
    """
    Fetches daily time series from Twelve Data for a specific symbol.
    """
    base_url = "https://api.twelvedata.com/time_series"
    params = {
        "symbol": symbol,
        "interval": "1day",
        "outputsize": lookback_days,
        "apikey": api_key,
        "order": "ASC"
    }
    
    try:
        response = requests.get(base_url, params=params)
        data = response.json()
        
        if "values" in data:
            df = pd.DataFrame(data["values"])
            df['datetime'] = pd.to_datetime(df['datetime'])
            df['close'] = pd.to_numeric(df['close'])
            df.set_index('datetime', inplace=True)
            return df['close']
        else:
            # Handle API errors silently or print if needed
            # print(f"TD Error {symbol}: {data.get('message', 'Unknown error')}")
            return None
    except Exception as e:
        return None

def get_market_data(tickers):
    today_str = date.today().strftime("%Y-%m-%d")
    filename = f'my_watchlist_data_{today_str}.pkl'
    
    if os.path.exists(filename) and not FORCE_UPDATE:
        print(f"   [CACHE] Loading Data from {filename}...")
        return pd.read_pickle(filename)
    
    # Initialize empty DataFrame
    all_data = pd.DataFrame()
    
    # ---------------------------------------------------------
    # PHASE 1: CHUNKED YAHOO DOWNLOAD (To prevent Rate Limit)
    # ---------------------------------------------------------
    # Yahoo blocks if you request 400 symbols at once with threads.
    # We will request in chunks of 25.
    
    chunk_size = 25
    total_chunks = (len(tickers) // chunk_size) + 1
    
    print(f"   [WEB] Phase 1: Downloading via Yahoo Finance (Chunked to avoid ban)...")
    
    for i in range(0, len(tickers), chunk_size):
        chunk = tickers[i:i + chunk_size]
        if not chunk: continue
        
        try:
            # Note: threads=False is slower but safer for rate limits on Colab
            batch_data = yf.download(chunk, period="6mo", interval="1d", progress=False, auto_adjust=True, threads=False)
            
            # Handle case where only 1 ticker is downloaded (returns Series or different shape)
            if 'Close' in batch_data:
                closes = batch_data['Close']
            else:
                closes = batch_data # Fallback
            
            # Merge into main dataframe
            if all_data.empty:
                all_data = closes
            else:
                # Use join or concat
                all_data = pd.concat([all_data, closes], axis=1)
                
            print(f"      -> Processed chunk {i//chunk_size + 1}/{total_chunks}")
            
            # SLEEP to reset Yahoo's rate limiter
            time.sleep(1.5) 
            
        except Exception as e:
            print(f"      ! Chunk failed: {e}")

    # ---------------------------------------------------------
    # PHASE 2: FALLBACK TO TWELVE DATA
    # ---------------------------------------------------------
    
    # Identify which tickers are completely missing (columns full of NaNs or not present)
    downloaded_cols = all_data.columns.tolist()
    missing_tickers = [t for t in tickers if t not in downloaded_cols or all_data[t].isna().all()]
    
    if missing_tickers and TD_API_KEY != "YOUR_TWELVE_DATA_API_KEY_HERE":
        print(f"\n   [RETRY] Phase 2: Using Twelve Data for {len(missing_tickers)} missing symbols...")
        print("      (Note: Free Tier allows ~8 requests/minute. This may take time.)")
        
        count = 0
        for symbol in missing_tickers:
            # Map Yahoo ticker format back to standard (e.g. BRK-B -> BRK.B) if needed
            # Twelve Data usually prefers dots for classes, e.g. BRK.B
            td_symbol = symbol.replace('-', '.') 
            if td_symbol == "^SPX": td_symbol = "SPX" # Adjust indices if needed
            
            s_data = fetch_twelve_data(td_symbol, TD_API_KEY)
            
            if s_data is not None:
                # Rename series to match DataFrame column
                s_data.name = symbol
                # Add to dataframe
                if symbol in all_data.columns:
                    all_data[symbol] = s_data
                else:
                    all_data = pd.concat([all_data, s_data], axis=1)
                print(f"      -> Recovered via TwelveData: {symbol}")
            else:
                print(f"      -> Failed on TwelveData: {symbol}")

            # Rate Limiting for Twelve Data (Free tier is strict)
            count += 1
            if count % 8 == 0:
                print("      ...sleeping for API limits...")
                time.sleep(60) # Wait 1 min after 8 requests (Free tier limit)
            else:
                time.sleep(1) # Small buffer

    elif missing_tickers:
        print(f"\n   [WARNING] {len(missing_tickers)} symbols missing. Add a valid Twelve Data Key to recover them.")

    # Save to cache
    all_data.to_pickle(filename)
    return all_data

# ==========================================
# 3. MAIN SCANNER
# ==========================================
def run_scanner():
    print("--- STEP 1: PROCESSING TICKER LIST ---")
    yahoo_tickers, reverse_map = get_clean_tickers()
    print(f"   Loaded {len(yahoo_tickers)} unique symbols.")
    
    print("\n--- STEP 2: MARKET DATA ---")
    data = get_market_data(yahoo_tickers)
    
    print("\n--- STEP 3: ANALYZING ZONES ---")
    recent_data = data.tail(LOOKBACK_DAYS)
    
    premium_list = []
    discount_list = []
    
    for y_ticker in recent_data.columns:
        try:
            series = recent_data[y_ticker].dropna()
            if series.empty: continue
            
            curr = series.iloc[-1]
            hi   = series.max()
            lo   = series.min()
            rng  = hi - lo
            
            if rng == 0: continue
            
            loc = (curr - lo) / rng
            tv_ticker = reverse_map.get(y_ticker, y_ticker)
            
            item = {'ticker': tv_ticker, 'loc': round(loc*100, 1), 'price': round(curr, 2)}
            
            if loc >= (1.0 - (TOP_PCT/100)):
                premium_list.append(item)
            elif loc <= (BTM_PCT/100):
                discount_list.append(item)
                
        except Exception:
            continue

    # ==========================================
    # FILTERING (KEEP ONLY TOP 25)
    # ==========================================
    
    # Sort Ascending (Lowest % first)
    discount_list.sort(key=lambda x: x['loc'])
    final_discount = discount_list[:MAX_RESULTS]
    
    # Sort Descending (Highest % first)
    premium_list.sort(key=lambda x: x['loc'], reverse=True)
    final_premium = premium_list[:MAX_RESULTS]

    # ==========================================
    # OUTPUT
    # ==========================================
    print("\n" + "="*60)
    print(f"MOST DISCOUNTED (Showing Top {len(final_discount)})")
    print("="*60)
    for s in final_discount: 
        print(f"{s['ticker']:<8} {s['loc']:<6}% ${s['price']}")

    print("\n" + "="*60)
    print(f"MOST PREMIUM (Showing Top {len(final_premium)})")
    print("="*60)
    for s in final_premium:
        print(f"{s['ticker']:<8} {s['loc']:<6}% ${s['price']}")

    # ==========================================
    # TRADINGVIEW IMPORT STRINGS
    # ==========================================
    print("\n\n" + "#"*60)
    print("TRADINGVIEW IMPORT STRINGS (COPY & PASTE)")
    print("#"*60)
    
    print(f"\n>>> DISCOUNT LIST (Best {len(final_discount)} candidates):")
    print(", ".join([x['ticker'] for x in final_discount]))
    
    print(f"\n>>> PREMIUM LIST (Best {len(final_premium)} candidates):")
    print(", ".join([x['ticker'] for x in final_premium]))

run_scanner()
